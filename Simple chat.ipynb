# %%
import os
import google.generativeai as genai

os.environ["GOOGLE_API_KEY"] = "API_KEY"  # stays only for this kernel

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

model = genai.GenerativeModel("gemini-2.5-flash")
response = model.generate_content("Give me 5 ideas for making money with ChatGPT")
print(response.text)
# Out:
# ChatGPT is an incredibly versatile tool that can significantly boost productivity and creativity. Here are 5 ideas for making money with it, ranging from services to product creation:
#
# 1.  **Content Creation & Marketing Service:**
#     *   **Idea:** Offer services to small businesses, solopreneurs, or busy professionals who need regular content but lack the time or resources to create it themselves.
#     *   **How ChatGPT Helps:**
#         *   **Blog Posts & Articles:** Generate outlines, draft entire articles (which you then edit, fact-check, and humanize), brainstorm topics, and create SEO-friendly content.
#         *   **Social Media Content:** Produce engaging captions, hashtags, and post ideas for various platforms (Facebook, Instagram, LinkedIn, X).
#         *   **Email Newsletters:** Draft compelling subject lines, body copy, and calls to action for email marketing campaigns.
# ...

# %%
import os
import google.generativeai as genai


os.environ["GOOGLE_API_KEY"] = "AIzaSyCaPgdEcZ0bbzu261Ud0PI-0ScWMmDQdgA"  # stays only for this kernel
# Configure API key
genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# Create the model
model = genai.GenerativeModel("gemini-2.5-flash")


messages = []

# System instruction
system_message = input("What kind of chatbot would you like to have?\n")
messages.append({
    "role": "user","parts": [{"text": f"System instruction: {system_message}"}]
})

print("Your new assistant is ready! Type 'quit()' to exit.\n")

while True:
    user_input = input("> ")

    if user_input.strip() == "quit()":
        print("Chat ended.")
        break

    # Append user message
    messages.append({
        "role": "user",
        "parts": [{"text": user_input}]
    })

    # Generate response
    response = model.generate_content(messages)

    reply = response.text
    print("\nAssistant:", reply, "\n")

    # Save assistant reply
    messages.append({
        "role": "model",
        "parts": [{"text": reply}]
    })
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      11 messages = []
#      13 # System instruction
# ---> 14 system_message = input("What kind of chatbot would you like to have?\n")
#      15 messages.append({
#      16     "role": "user","parts": [{"text": f"System instruction: {system_message}"}]
#      17 })
#      19 print("Your new assistant is ready! Type 'quit()' to exit.\n")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# ...

# %%
import os
import gradio as gr
import google.generativeai as genai

# ----------------------------------------
# 1. Configure Gemini API key
# ----------------------------------------

os.environ["GOOGLE_API_KEY"] = "AIzaSyCaPgdEcZ0bbzu261Ud0PI-0ScWMmDQdgA"  # stays only for this kernel

genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))

# ----------------------------------------
# 2. Conversation memory (Gemini format)
# ----------------------------------------
messages = [{
    "role": "user",
    "parts": [{"text": "System instruction: You are a financial expert specializing in real estate investment and negotiation."}]
}]

# ----------------------------------------
# 3. Chat Function
# ----------------------------------------
def CustomGemini(user_input):
    # Add user message
    messages.append({
        "role": "user",
        "parts": [{"text": user_input}]
    })

    # Gemini model call
    model = genai.GenerativeModel("gemini-2.5-flash")
    response = model.generate_content(messages)

    reply = response.text

    # Add assistant reply
    messages.append({
        "role": "model",
        "parts": [{"text": reply}]
    })

    return reply

# ----------------------------------------
# 4. Gradio Interface
# ----------------------------------------
demo = gr.Interface(
    fn=CustomGemini,
    inputs="text",
    outputs="text",
    title="My Saving Assistant (Gemini)"
)

demo.launch(share=True)
